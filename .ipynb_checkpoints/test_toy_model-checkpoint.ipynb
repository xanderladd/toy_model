# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import h5py
from neuron import h
import plot_helper as ph
#from scalebary import add_scalebar

# %%
# params_path = './params/params_bbp_full.hdf5'
# params_file = h5py.File(params_path, 'r')
# orig_params = params_file['orig_full'][0]
# bbp_best_pair_plot_path = './plots/'
orig_params = [0.12, 0.036, 0.0003]

# %%
stims = h5py.File('./stims/stims_full.hdf5', 'r')

stim_names = stims.keys()

# %%
toy_model_plot_sur_path = './plots/surrogate/'
#for stim_name in list(stim_names)[:1]:
#    stim = stims[stim_name][:]
#    ph.run_and_plot_voltage_response_single(orig_params, stim, toy_model_plot_sur_path + stim_name, stim_name)

# %%
stim_to_plot = 'chirp_f_0_to_0.18_a_3_to_9'
stim = stims[stim_to_plot][:]

ph.run_and_plot_voltage_response_single(orig_params, stim, toy_model_plot_sur_path + stim_to_plot, stim_to_plot)
# Out:
# 15
# 500
# 	1
# finshed run matrix

# %%
scores_folder = './scores/'
score_file_names = os.listdir(scores_folder)

# %%
# for score_name in score_file_names:
#     score_dict = h5py.File(scores_folder+score_name, 'r')
#     plt.figure()
#     for sf_name in score_dict.keys():
#         if 'norm' in sf_name:
#             score = score_dict[sf_name][:]
#             plt.plot(score)
#     plt.show()

# %%
volts_folder = './volts/'
volts_file_names = os.listdir(volts_folder)

# %%
stim_to_plot = 'chirp_f_0_to_0.18_a_3_to_9'
volts = h5py.File(volts_folder+stim_to_plot + '_volts.hdf5', 'r')
pin_volts = volts['pin_' + stim_to_plot]
print(len(pin_volts))
# Out:
# 100

# %%
stim_to_plot = 'he_3_15_5'
param_set = h5py.File('./params/params_hh_full_1000.hdf5')['pin_1000_full']
#volts = h5py.File(volts_folder+stim_to_plot + '_volts.hdf5', 'r')
#pin_volts = volts['pin_' + stim_to_plot]
stim = stims[stim_to_plot][:]
toy_model_plot_sur_path = './plots/pin_volts/'
dt = 0.02
ntimestep = 10000
timestamps = np.array([dt for i in range(ntimestep)])
#times = np.cumsum(timestamps)
#for i in range(1000):
    #curr_volts = pin_volts[i]
    #ph.plot_stim_volts_pair(stim, [curr_volts], f'#{i}', '', f'{toy_model_plot_sur_path}{stim_to_plot}_{i}' ) 

# Select index 

indices = [11,801]
for i in indices:
    curr_params = param_set[i]
    ph.run_and_plot_voltage_response_single(curr_params, stim, f'{toy_model_plot_sur_path}{stim_to_plot}_{i}', f'#{i}')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# finshed run matrix
# finshed run matrix

# %%
for volts_name in volts_file_names:
    volts = h5py.File(volts_folder+volts_name, 'r')
    for key in volts.keys():
        if 'orig' in key:
            volts_orig = volts[key][:]
        if 'pin' in key:
            for i in range(100):
                volt = volts[key][i]
                if np.sum(volts_orig - volt) != 0:
                    print('Nonzero')
# Out:
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# ...
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero
# Nonzero

# %%
params_file = './run_volts_hh/params/params_hh_full_1000.hdf5'
parmas = h5py.File(params_file, 'r')

params_orig = parmas['orig_full'][0]
params_pin = parmas['pin_1000_full'][:]
print(params_orig)
print(params_pin)
# Out:
# [0.12   0.036  0.0003]
# [[1.18562656e-01 3.63499150e-02 2.87330541e-04]
#  [1.19178007e-01 3.43237598e-02 2.98953334e-04]
#  [1.14382965e-01 3.49671416e-02 2.91270165e-04]
#  ...
#  [1.16105887e+00 1.36861136e-01 6.15083366e-05]
#  [1.16768498e+00 1.35405601e-01 1.64447981e-04]
#  [1.19449758e+00 2.99594059e-01 2.51619115e-03]]

# %%
stim = stims[list(stim_names)[0]][:]
v_s = []
# for p in params_pin:
#     v = run_single_volts([1,2,3], stim)
#     plt.plot(v[0])
for p1 in np.linspace(0.1, 1, 5):
    for p2 in np.linspace(0.03, 0.1, 5):
        for p3 in np.linspace(0.003, 0.01, 5):
            v = ph.run_single_volts([p1, p2, p3], stim)
            plt.plot(v[0])
plt.show()
# Out:
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix
# finshed run matrix

# %% [markdown]
# # Best Pair

# %%
import scipy.stats as stat
from tqdm import tqdm
import operator
import math

def compute_spearman(scores):
    perfect_distribution = np.cumsum(np.ones(len(scores)))
    spearman = stat.spearmanr(scores, perfect_distribution)[0]
    if math.isnan(spearman):
        spearman = 0
    return spearman

def compute_best_pair(scores_path):
    score_names = os.listdir(scores_path)
    spearman_dict = {}
    for score_name in tqdm(score_names):
        scores = h5py.File(scores_path+score_name)
        stim_name = score_name.replace('_scores.hdf5', '')
        sf_names = sorted([e for e in list(scores.keys()) if 'norm_pin_scores_' in e])
        for sf_name in sf_names:
            spearman_val = compute_spearman(scores[sf_name][:])
            spearman_dict[(stim_name, sf_name.replace('norm_pin_scores_', ''))] = spearman_val
    best_pair = max(spearman_dict.items(), key=operator.itemgetter(1))[0]
    best_value = spearman_dict[best_pair]
    return best_pair, best_value
def compute_specific_pair(scores_path,stim,sf):
    score_names = os.listdir(scores_path)
    stim_name = f'{scores_path}{stim}_scores.hdf5'
    #h5py.File(scores_path+score_name)
    stim_score_names = h5py.File(stim_name)
    #sf_names = sorted([e for e in list(stim_score_names.keys()) if 'norm_pin_scores_' in e])
    #print(stim_score_names.keys())
    sf_name = f'norm_pin_scores_{sf}'
    spearman_val = compute_spearman(stim_score_names[sf_name][:])
    return [stim,sf],spearman_val
def plot_scores_best_pair(best_pair, score_path, title, plot_save_path=None):
    scores = h5py.File(scores_path+best_pair[0]+'_scores.hdf5')['norm_pin_scores_'+best_pair[1]][:]
    plt.figure(figsize=(ph.cm_to_in(3.5), ph.cm_to_in(3.5)))
    #plt.title(title)
    #plt.xlabel('Parameter Set Rank')
    #plt.ylabel('Weighted Score')
    #plt.ylim([0,1])
    #plt.xlim([0,10000])
    
    plt.locator_params(axis='x', nbins=2)
    plt.locator_params(axis='y', nbins=3)
    time_step = range(len(scores))
    plt.scatter(time_step, scores, s=1, color='black')
    if plot_save_path:
        plt.savefig(plot_save_path+'.pdf', format='pdf', dpi=1000, bbox_inches="tight")

# %%
scores_path = './scores_1000/'
stim_to_plot = 'chirp_f_0_to_0.18_a_3_to_9'
sf = 'AP_height'
#stim_to_plot = 'he_3_15_5'
pair_to_plot,_spearman_val = compute_specific_pair(scores_path,stim_to_plot,sf)
toy_model_plot_path = f'./plots/spearman_{stim_to_plot}_{sf}'
plot_scores_best_pair(pair_to_plot, scores_path, f'{stim_to_plot}_{sf}', toy_model_plot_path)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.

# %%
scores_path = './scores_1000/'
best_pair, best_value = compute_best_pair(scores_path)
# Out:
#   0%|                                                                                                                                                                                                               | 0/303 [00:00<?, ?it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:4196: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
#   0%|▋                                                                                                                                                                                                      | 1/303 [00:00<00:32,  9.43it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   1%|█▉                                                                                                                                                                                                     | 3/303 [00:00<00:29, 10.06it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   1%|██▋                                                                                                                                                                                                    | 4/303 [00:00<00:30,  9.95it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   2%|███▉                                                                                                                                                                                                   | 6/303 [00:00<00:29, 10.12it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   3%|█████▎                                                                                                                                                                                                 | 8/303 [00:00<00:24, 11.84it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   3%|██████▌                                                                                                                                                                                               | 10/303 [00:00<00:25, 11.37it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   4%|███████▊                                                                                                                                                                                              | 12/303 [00:01<00:25, 11.43it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   5%|█████████▏                                                                                                                                                                                            | 14/303 [00:01<00:26, 10.75it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   5%|██████████▍                                                                                                                                                                                           | 16/303 [00:01<00:25, 11.09it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   6%|███████████▊                                                                                                                                                                                          | 18/303 [00:01<00:25, 11.04it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   7%|█████████████                                                                                                                                                                                         | 20/303 [00:01<00:25, 10.95it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   7%|██████████████▍                                                                                                                                                                                       | 22/303 [00:01<00:26, 10.70it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   8%|███████████████▋                                                                                                                                                                                      | 24/303 [00:02<00:25, 10.77it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   9%|████████████████▉                                                                                                                                                                                     | 26/303 [00:02<00:24, 11.16it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   9%|██████████████████▎                                                                                                                                                                                   | 28/303 [00:02<00:24, 11.05it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  10%|███████████████████▌                                                                                                                                                                                  | 30/303 [00:02<00:24, 10.98it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  11%|████████████████████▉                                                                                                                                                                                 | 32/303 [00:02<00:24, 10.95it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  11%|██████████████████████▏                                                                                                                                                                               | 34/303 [00:03<00:25, 10.49it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  12%|███████████████████████▌                                                                                                                                                                              | 36/303 [00:03<00:29,  9.20it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  12%|████████████████████████▏                                                                                                                                                                             | 37/303 [00:03<00:28,  9.35it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  13%|█████████████████████████▍                                                                                                                                                                            | 39/303 [00:03<00:27,  9.70it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  13%|██████████████████████████▏                                                                                                                                                                           | 40/303 [00:03<00:27,  9.70it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  14%|██████████████████████████▊                                                                                                                                                                           | 41/303 [00:03<00:27,  9.46it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  14%|████████████████████████████                                                                                                                                                                          | 43/303 [00:04<00:26,  9.81it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  15%|████████████████████████████▊                                                                                                                                                                         | 44/303 [00:04<00:27,  9.47it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  15%|██████████████████████████████                                                                                                                                                                        | 46/303 [00:04<00:25, 10.03it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  16%|███████████████████████████████▎                                                                                                                                                                      | 48/303 [00:04<00:25, 10.10it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  17%|████████████████████████████████▋                                                                                                                                                                     | 50/303 [00:04<00:24, 10.51it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  17%|█████████████████████████████████▉                                                                                                                                                                    | 52/303 [00:04<00:23, 10.70it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  18%|███████████████████████████████████▎                                                                                                                                                                  | 54/303 [00:05<00:23, 10.72it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  18%|████████████████████████████████████▌                                                                                                                                                                 | 56/303 [00:05<00:23, 10.58it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  19%|█████████████████████████████████████▉                                                                                                                                                                | 58/303 [00:05<00:22, 10.78it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  20%|███████████████████████████████████████▏                                                                                                                                                              | 60/303 [00:05<00:22, 10.83it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  20%|████████████████████████████████████████▌                                                                                                                                                             | 62/303 [00:05<00:22, 10.50it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  21%|█████████████████████████████████████████▊                                                                                                                                                            | 64/303 [00:06<00:23, 10.15it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  22%|███████████████████████████████████████████▏                                                                                                                                                          | 66/303 [00:06<00:23, 10.08it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  22%|████████████████████████████████████████████▍                                                                                                                                                         | 68/303 [00:06<00:22, 10.22it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  23%|█████████████████████████████████████████████▋                                                                                                                                                        | 70/303 [00:06<00:21, 10.68it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  24%|███████████████████████████████████████████████                                                                                                                                                       | 72/303 [00:06<00:21, 10.94it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  24%|████████████████████████████████████████████████▎                                                                                                                                                     | 74/303 [00:06<00:20, 11.09it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  25%|█████████████████████████████████████████████████▋                                                                                                                                                    | 76/303 [00:07<00:20, 11.34it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  26%|██████████████████████████████████████████████████▉                                                                                                                                                   | 78/303 [00:07<00:19, 11.35it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  26%|████████████████████████████████████████████████████▎                                                                                                                                                 | 80/303 [00:07<00:19, 11.45it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  27%|██████████████████████████████████████████████████████▏                                                                                                                                               | 83/303 [00:07<00:17, 12.70it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  28%|███████████████████████████████████████████████████████▌                                                                                                                                              | 85/303 [00:07<00:17, 12.34it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# ...
#  90%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                  | 274/303 [00:24<00:02, 11.93it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  91%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                 | 276/303 [00:24<00:02, 11.77it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  92%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                | 278/303 [00:24<00:02, 11.51it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  92%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████               | 280/303 [00:24<00:02, 11.03it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  93%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎             | 282/303 [00:25<00:01, 11.32it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  94%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋            | 284/303 [00:25<00:01, 11.14it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  94%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉           | 286/303 [00:25<00:01, 11.24it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  95%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏         | 288/303 [00:25<00:01, 11.45it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  96%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌        | 290/303 [00:25<00:01, 11.53it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊       | 292/303 [00:25<00:00, 11.54it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  97%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏     | 294/303 [00:26<00:00, 11.56it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  98%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍    | 296/303 [00:26<00:00, 11.40it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  98%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋   | 298/303 [00:26<00:00, 11.67it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████  | 300/303 [00:26<00:00, 11.52it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎| 302/303 [00:26<00:00, 11.61it/s]C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 303/303 [00:26<00:00, 11.26it/s]

# %%
toy_model_best_pair_plot_path = './plots/scores_best_pair'
plot_scores_best_pair(best_pair, scores_path, 'HH Best Pair', toy_model_best_pair_plot_path)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.

# %%
# toy_model_best_pair_plot_path = './plots/scores_best_pair'
# bbp_full_best_pair_opt_path = './objectives/best_pair_bbp_full.hdf5'
# opt_file_best_pair = h5py.File(bbp_full_best_pair_opt_path, 'r')
# ordered_score_function_list = [e.decode('ascii') for e in opt_file_best_pair['ordered_score_function_list'][:]]
# opt_stim_list_best_pair = [e.decode('ascii') for e in opt_file_best_pair['stims_optimal_order'][:]]
# optimal_weight_list_best_pair = opt_file_best_pair['optimal_weight_list'][:]
# plot_comb_scores(ordered_score_function_list, opt_stim_list_best_pair, optimal_weight_list_best_pair, bbp_full_score_path, 'BBP Best Pair', bbp_best_pair_plot_path)
# print('Stims used to train:')
# for e in opt_stim_list_best_pair:
#     print(e)

# %%
def cm_to_in(cm):
    return cm/2.54
def plot_comb_scores(opt_path, score_path, title, plot_save_path=None):
    opt_result = h5py.File(opt_path)
    print(opt_result.keys())
    ordered_score_function_list = [e.decode('ascii') for e in opt_result['ordered_score_function_list'][:]]
    optimization_stim_names = [e.decode('ascii') for e in opt_result['opt_stim_name_list'][:]]
    optimization_weightes = opt_result['opt_weight_list'][:]
    best_stims_score_list = []
    for score_name in optimization_stim_names:
        curr_score_data = h5py.File(score_path+score_name+'_scores.hdf5', 'r')
        for sf in ordered_score_function_list:
            curr_stim_sf_pair = curr_score_data['norm_pin_scores_'+sf][:]
            best_stims_score_list.append(curr_stim_sf_pair)
    combined_score = sum([best_stims_score_list[i]*optimization_weightes[i] for i in range(len(optimization_weightes))])
    plt.figure(figsize=(cm_to_in(8.5), cm_to_in(5)))
    plt.title(title)
    plt.xlabel('Parameter Set Rank')
    plt.ylabel('Weighted Score')
    time_step = range(len(combined_score))
    plt.scatter(time_step, combined_score, s=1, color='black')
    if plot_save_path:
        plt.savefig(plot_save_path+'.pdf', format='pdf', dpi=1000, bbox_inches="tight")
def plot_comb_scores_full(ordered_score_function_list, optimization_stim_names, optimization_weightes, score_path, title, plot_save_path=None):
    best_stims_score_list = []
    for score_name in optimization_stim_names:
        curr_score_data = h5py.File(score_path+score_name+'_scores.hdf5', 'r')
        for sf in ordered_score_function_list:
            curr_stim_sf_pair = curr_score_data['norm_pin_scores_'+sf][:]
            best_stims_score_list.append(curr_stim_sf_pair)
    combined_score = sum([best_stims_score_list[i]*optimization_weightes[i] for i in range(len(optimization_weightes))])
    plt.figure(figsize=(cm_to_in(3.5), cm_to_in(3.5)))
    #plt.title(title)
    #plt.xlabel('Parameter Set Rank')
    #plt.ylabel('Weighted Score')
    #plt.ylim([0,1])
    #plt.xlim([0,10000])
    
    plt.locator_params(axis='x', nbins=2)
    plt.locator_params(axis='y', nbins=3)
    time_step = range(len(combined_score))
    plt.scatter(time_step, combined_score, s=1, color='black')
    if plot_save_path:
        plt.savefig(plot_save_path+'.pdf', format='pdf', dpi=1000, bbox_inches="tight")

# %% [markdown]
# # Single-stim (Best)

# %%
toy_model_plot_path = './plots/single_stim_scores'
toy_model_opt_path_single = './analyze_p/optimization_results_path/opt_result_single_stim_hh_full_1000.hdf5'
toy_model_opt_path_multi = './analyze_p/optimization_results_path/multi_stim_hh_full_20_stims_1000.hdf5'
toy_model_score_path = './scores_1000/'
toy_model_multiple_stim_opt_file = h5py.File(toy_model_opt_path_multi, 'r')
ordered_score_function_list = [e.decode('ascii') for e in toy_model_multiple_stim_opt_file['ordered_score_function_list'][:]]
opt_file_single_stim = h5py.File(toy_model_opt_path_single, 'r')
train_stim_name_single_stim = opt_file_single_stim['stims_optimal_order'][0].decode('ascii')
optimal_weight_list_single_stim = opt_file_single_stim[train_stim_name_single_stim][:]
plot_comb_scores_full(ordered_score_function_list, [train_stim_name_single_stim], optimal_weight_list_single_stim, toy_model_score_path, 'HH Single Stimulus', toy_model_plot_path)
print('Stims used to train:', train_stim_name_single_stim)
# Out:
# Stims used to train: chirp_f_0.14_to_0_a_9_to_3

# %%
#single Stim Chosen
print(toy_model_multiple_stim_opt_file.keys())
# Out:
# <KeysViewHDF5 ['opt_stim_name_list', 'opt_weight_list', 'ordered_score_function_list']>

# %% [markdown]
# # Multi-Stim

# %%
toy_model_opt_path = './analyze_p/optimization_results_path/multi_stim_hh_full_20_stims_1000.hdf5'
toy_model_score_path = './scores_1000/'
toy_model_plot_path = './plots/multi_stim_scores'
plot_comb_scores(toy_model_opt_path, toy_model_score_path, 'HH Full', toy_model_plot_path)
print('Stims used to train:')
train_stim_names_full = h5py.File(toy_model_opt_path, 'r')['opt_stim_name_list'][:]
for e in train_stim_names_full:
    print(e.decode('ascii'))
# Out:
# <KeysViewHDF5 ['opt_stim_name_list', 'opt_weight_list', 'ordered_score_function_list']>
# Stims used to train:
# chirp_f_0.14_to_0_a_9_to_3
# chirp_f_0.14_to_0_a_9_to_9
# chirp_f_0_to_0.14_a_3_to_9
# chirp_f_0_to_0.16_a_3_to_9
# chirp_f_0.16_to_0_a_9_to_9
# chirp_f_0.22_to_0_a_9_to_9
# chirp_f_0.26_to_0_a_9_to_9
# chirp_f_0.24_to_0_a_3_to_9
# chirp_f_0.24_to_0_a_9_to_9
# chirp_f_0.2_to_0_a_9_to_9
# chirp_f_0.14_to_0_a_6_to_6
# chirp_f_0.28_to_0_a_9_to_9
# chirp_f_0.16_to_0_a_3_to_9
# sin_f_0.2_a_3_m_0
# chirp_f_0_to_0.18_a_3_to_9
# chirp_f_0.12_to_0_a_9_to_9
# chirp_f_0.12_to_0_a_6_to_6
# chirp_f_0_to_0.14_a_3_to_6
# chirp_f_0.12_to_0_a_6_to_3
# chirp_f_0.24_to_0_a_6_to_6

# %%
plt.rcParams['axes.spines.right'] = False
plt.rcParams['axes.spines.top'] = False
plt.rcParams['font.sans-serif'] = "Arial"
plt.rcParams['font.family'] = "sans-serif"
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

tick_major = 6
tick_minor = 4
plt.rcParams["xtick.major.size"] = tick_major
plt.rcParams["xtick.minor.size"] = tick_minor
plt.rcParams["ytick.major.size"] = tick_major
plt.rcParams["ytick.minor.size"] = tick_minor

font_small = 12
font_medium = 13
font_large = 14
plt.rc('font', size=font_small)          # controls default text sizes
plt.rc('axes', titlesize=font_medium)    # fontsize of the axes title
plt.rc('axes', labelsize=font_medium)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=font_small)    # fontsize of the tick labels
plt.rc('ytick', labelsize=font_small)    # fontsize of the tick labels
plt.rc('legend', fontsize=font_small)    # legend fontsize
plt.rc('figure', titlesize=font_large)   # fontsize of the figure title

def cm_to_in(cm):
    return cm/2.54

def plot_stim_volts_pair(stim, volts,times, title_stim, title_volts, file_path_to_save=None):
    fig,axs = plt.subplots(2,figsize=(cm_to_in(30), cm_to_in(20)),gridspec_kw={'height_ratios': [1, 4]})
    axs[0].set_title(title_stim)
    axs[0].plot(times,stim, color='black', linewidth=0.5)
#    add_scalebar(axs[0])
    axs[0].set_title('Voltage Response '+title_volts)
    
    axs[1].plot(times,volts, label='response', color='black',linewidth=1)
#    add_scalebar(axs[1])
    #plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
    #plt.tight_layout(pad=1)
    #if file_path_to_save:
    #    plt.savefig(file_path_to_save+'.pdf', format='pdf', dpi=1000, bbox_inches="tight")
    return fig,axs

# Running a single volt
def run_single_volts(param_set, stim_data, ntimestep = 10000, dt = 0.02):
    run_file = './run_model_cori.hoc'
    h.load_file(run_file)
    total_params_num = len(param_set)
    timestamps = np.array([dt for i in range(ntimestep)])
    h.curr_stim = h.Vector().from_python(stim_data)
    h.transvec = h.Vector(total_params_num, 1).from_python(param_set)
    h.stimtime = h.Matrix(1, len(timestamps)).from_vector(h.Vector().from_python(timestamps))
    h.ntimestep = ntimestep
    
    h.runStim()
    out = h.vecOut.to_python()
    return np.array(out),np.cumsum(timestamps)

def run_and_plot_voltage_response(base, stim_data, stim_title, response_title, file_save_path=None):
    volts_orig,times= run_single_volts(base, stim_data)
    fig, axs = plot_stim_volts_pair(stim_data, volts_orig, times, stim_title, response_title, file_save_path)
    return fig, axs


def plot_comb_scores(opt_path, score_path, title, plot_save_path=None):
    opt_result = h5py.File(opt_path)
    ordered_score_function_list = [e.decode('ascii') for e in opt_result['ordered_score_function_list'][:]]
    optimization_stim_names = [e.decode('ascii') for e in opt_result['opt_stim_name_list'][:]]
    optimization_weightes = opt_result['opt_weight_list'][:]
    best_stims_score_list = []
    for score_name in optimization_stim_names:
        curr_score_data = h5py.File(score_path+score_name+'_scores.hdf5', 'r')
        for sf in ordered_score_function_list:
            curr_stim_sf_pair = curr_score_data['norm_pin_scores_'+sf][:]
            best_stims_score_list.append(curr_stim_sf_pair)
    combined_score = sum([best_stims_score_list[i]*optimization_weightes[i] for i in range(len(optimization_weightes))])
    plt.figure(figsize=(cm_to_in(8.5), cm_to_in(5)))
    plt.title(title)
    plt.xlabel('Parameter Set Rank')
    plt.ylabel('Weighted Score')
    time_step = range(len(combined_score))
    plt.scatter(time_step, combined_score, s=1, color='black')
    if plot_save_path:
        plt.savefig(plot_save_path+'.pdf', format='pdf', dpi=1000, bbox_inches="tight")
